# %%
import pandas as pd
import time
import random

# %%
def pull_reg_data(team, year):
    url = f"https://www.basketball-reference.com/teams/{team}/{year}/gamelog/"
    try:
        data = pd.read_html(url)
        reg_szn = data[0]
        
       # reg_szn = reg_szn.drop(index=reg_rows_to_drop)
        return reg_szn
    
    except Exception as e:
        print(f"Error retrieving data for {team} in {year}: {e}")
        return pd.DataFrame()  # Return an empty DataFrame in case of error

# %%
boxscores_complete_new = pd.DataFrame() # 2020-2024

# %%
teams = ["ATL", "BOS", "BRK", "CHO", "CHI", "CLE", 
         "DAL", "DEN", "DET", "GSW", "HOU", "IND", 
         "LAC", "LAL", "MEM", "MIA", "MIL", "MIN",
         "NOP", "NYK", "OKC", "ORL", "PHI", "PHO", 
         "POR", "SAC", "SAS", "TOR", "UTA", "WAS"]

years = list(range(2015, 2026)) 

for year in years:
    random.shuffle(teams)  # Shuffle team order for the current year

    for team in teams:
        attempts = 0
        success = False

        while attempts < 3 and not success:
            temp = pull_reg_data(team, year) 
            temp["team"] = team
            temp["season"] = year

            if not temp.empty:
                boxscores_complete_new = pd.concat([boxscores_complete_new, temp], ignore_index=True)
                success = True
                print(f"Data retrieved successfully for {team} in {year}.")
            else:
                attempts += 1
                print(f"Attempt {attempts} failed for {team} in {year}. Retrying in 10 seconds.")
                time.sleep(10)

        if not success:
            print(f"Failed to retrieve data for {team} in {year} after 3 attempts.")

        time.sleep(6)

    print(f"Completed data collection for {year}.")
# Out:
# Data retrieved successfully for MEM in 2015.
# Data retrieved successfully for CHO in 2015.
# Data retrieved successfully for MIN in 2015.
# Data retrieved successfully for CHI in 2015.
# Data retrieved successfully for POR in 2015.
# Data retrieved successfully for NOP in 2015.
# Data retrieved successfully for LAC in 2015.
# Data retrieved successfully for LAL in 2015.
# Data retrieved successfully for ORL in 2015.
# Data retrieved successfully for NYK in 2015.
# Data retrieved successfully for GSW in 2015.
# Data retrieved successfully for ATL in 2015.
# Data retrieved successfully for DEN in 2015.
# Data retrieved successfully for HOU in 2015.
# Data retrieved successfully for DAL in 2015.
# Data retrieved successfully for UTA in 2015.
# Data retrieved successfully for SAS in 2015.
# Data retrieved successfully for CLE in 2015.
# Data retrieved successfully for DET in 2015.
# Data retrieved successfully for WAS in 2015.
# Data retrieved successfully for MIL in 2015.
# Data retrieved successfully for OKC in 2015.
# Data retrieved successfully for IND in 2015.
# Data retrieved successfully for BRK in 2015.
# Data retrieved successfully for MIA in 2015.
# Data retrieved successfully for PHO in 2015.
# Data retrieved successfully for SAC in 2015.
# Data retrieved successfully for TOR in 2015.
# Data retrieved successfully for PHI in 2015.
# Data retrieved successfully for BOS in 2015.
# Completed data collection for 2015.
# Data retrieved successfully for NYK in 2016.
# Data retrieved successfully for PHI in 2016.
# Data retrieved successfully for ORL in 2016.
# Data retrieved successfully for DAL in 2016.
# Data retrieved successfully for PHO in 2016.
# Data retrieved successfully for DEN in 2016.
# Data retrieved successfully for OKC in 2016.
# Data retrieved successfully for HOU in 2016.
# Data retrieved successfully for CHI in 2016.
# Data retrieved successfully for SAS in 2016.
# Data retrieved successfully for WAS in 2016.
# Data retrieved successfully for MIL in 2016.
# Data retrieved successfully for NOP in 2016.
# Data retrieved successfully for POR in 2016.
# Data retrieved successfully for BOS in 2016.
# Data retrieved successfully for BRK in 2016.
# Data retrieved successfully for MEM in 2016.
# Data retrieved successfully for CHO in 2016.
# Data retrieved successfully for TOR in 2016.
# Data retrieved successfully for LAL in 2016.
# Data retrieved successfully for DET in 2016.
# Data retrieved successfully for SAC in 2016.
# Data retrieved successfully for IND in 2016.
# Data retrieved successfully for GSW in 2016.
# Data retrieved successfully for UTA in 2016.
# Data retrieved successfully for LAC in 2016.
# Data retrieved successfully for MIA in 2016.
# Data retrieved successfully for MIN in 2016.
# Data retrieved successfully for CLE in 2016.
# Data retrieved successfully for ATL in 2016.
# Completed data collection for 2016.
# Data retrieved successfully for CLE in 2017.
# Data retrieved successfully for CHO in 2017.
# Data retrieved successfully for UTA in 2017.
# Data retrieved successfully for PHO in 2017.
# Data retrieved successfully for GSW in 2017.
# Data retrieved successfully for DET in 2017.
# Data retrieved successfully for WAS in 2017.
# Data retrieved successfully for PHI in 2017.
# Data retrieved successfully for LAC in 2017.
# Data retrieved successfully for MIL in 2017.
# Data retrieved successfully for LAL in 2017.
# Data retrieved successfully for TOR in 2017.
# Data retrieved successfully for NYK in 2017.
# Data retrieved successfully for MEM in 2017.
# Data retrieved successfully for BRK in 2017.
# Data retrieved successfully for SAS in 2017.
# Data retrieved successfully for HOU in 2017.
# Data retrieved successfully for MIA in 2017.
# Data retrieved successfully for ORL in 2017.
# Data retrieved successfully for NOP in 2017.
# Data retrieved successfully for IND in 2017.
# Data retrieved successfully for BOS in 2017.
# Data retrieved successfully for SAC in 2017.
# Data retrieved successfully for ATL in 2017.
# Data retrieved successfully for MIN in 2017.
# Data retrieved successfully for OKC in 2017.
# Data retrieved successfully for DAL in 2017.
# Data retrieved successfully for CHI in 2017.
# Data retrieved successfully for DEN in 2017.
# Data retrieved successfully for POR in 2017.
# Completed data collection for 2017.
# Data retrieved successfully for DEN in 2018.
# Data retrieved successfully for ATL in 2018.
# Data retrieved successfully for BRK in 2018.
# Data retrieved successfully for DET in 2018.
# Data retrieved successfully for BOS in 2018.
# Data retrieved successfully for MIN in 2018.
# Data retrieved successfully for TOR in 2018.
# Data retrieved successfully for PHI in 2018.
# Data retrieved successfully for GSW in 2018.
# Data retrieved successfully for SAC in 2018.
# Data retrieved successfully for MIL in 2018.
# Data retrieved successfully for DAL in 2018.
# Data retrieved successfully for NYK in 2018.
# Data retrieved successfully for HOU in 2018.
# Data retrieved successfully for MEM in 2018.
# Data retrieved successfully for UTA in 2018.
# Data retrieved successfully for NOP in 2018.
# Data retrieved successfully for ORL in 2018.
# Data retrieved successfully for LAC in 2018.
# Data retrieved successfully for LAL in 2018.
# Data retrieved successfully for WAS in 2018.
# Data retrieved successfully for CHI in 2018.
# Data retrieved successfully for CHO in 2018.
# Data retrieved successfully for MIA in 2018.
# Data retrieved successfully for CLE in 2018.
# Data retrieved successfully for SAS in 2018.
# Data retrieved successfully for OKC in 2018.
# Data retrieved successfully for PHO in 2018.
# Data retrieved successfully for IND in 2018.
# Data retrieved successfully for POR in 2018.
# Completed data collection for 2018.
# Data retrieved successfully for NOP in 2019.
# Data retrieved successfully for MEM in 2019.
# Data retrieved successfully for DET in 2019.
# Data retrieved successfully for TOR in 2019.
# Data retrieved successfully for LAL in 2019.
# Data retrieved successfully for BOS in 2019.
# Data retrieved successfully for ATL in 2019.
# Data retrieved successfully for LAC in 2019.
# Data retrieved successfully for HOU in 2019.
# Data retrieved successfully for CLE in 2019.
# Data retrieved successfully for DEN in 2019.
# Data retrieved successfully for WAS in 2019.
# Data retrieved successfully for CHI in 2019.
# Data retrieved successfully for IND in 2019.
# Data retrieved successfully for POR in 2019.
# Data retrieved successfully for BRK in 2019.
# Data retrieved successfully for GSW in 2019.
# Data retrieved successfully for DAL in 2019.
# Data retrieved successfully for UTA in 2019.
# Data retrieved successfully for OKC in 2019.
# Data retrieved successfully for PHI in 2019.
# Data retrieved successfully for ORL in 2019.
# Data retrieved successfully for MIL in 2019.
# Data retrieved successfully for SAS in 2019.
# Data retrieved successfully for NYK in 2019.
# Data retrieved successfully for MIA in 2019.
# Data retrieved successfully for CHO in 2019.
# Data retrieved successfully for MIN in 2019.
# Data retrieved successfully for SAC in 2019.
# Data retrieved successfully for PHO in 2019.
# Completed data collection for 2019.
# Data retrieved successfully for BOS in 2020.
# Data retrieved successfully for DET in 2020.
# Data retrieved successfully for NOP in 2020.
# Data retrieved successfully for DAL in 2020.
# Data retrieved successfully for OKC in 2020.
# Data retrieved successfully for MEM in 2020.
# Data retrieved successfully for BRK in 2020.
# Data retrieved successfully for CHI in 2020.
# Data retrieved successfully for SAC in 2020.
# Data retrieved successfully for POR in 2020.
# Data retrieved successfully for LAL in 2020.
# Data retrieved successfully for HOU in 2020.
# Data retrieved successfully for PHO in 2020.
# Data retrieved successfully for DEN in 2020.
# Data retrieved successfully for ORL in 2020.
# Data retrieved successfully for MIA in 2020.
# Data retrieved successfully for CLE in 2020.
# Data retrieved successfully for IND in 2020.
# Data retrieved successfully for CHO in 2020.
# Data retrieved successfully for ATL in 2020.
# Data retrieved successfully for SAS in 2020.
# Data retrieved successfully for MIL in 2020.
# Data retrieved successfully for MIN in 2020.
# Data retrieved successfully for TOR in 2020.
# Data retrieved successfully for WAS in 2020.
# Data retrieved successfully for UTA in 2020.
# Data retrieved successfully for GSW in 2020.
# Data retrieved successfully for PHI in 2020.
# Data retrieved successfully for NYK in 2020.
# Data retrieved successfully for LAC in 2020.
# Completed data collection for 2020.
# Data retrieved successfully for POR in 2021.
# Data retrieved successfully for SAC in 2021.
# Data retrieved successfully for TOR in 2021.
# Data retrieved successfully for MIL in 2021.
# Data retrieved successfully for DET in 2021.
# Data retrieved successfully for GSW in 2021.
# Data retrieved successfully for DAL in 2021.
# Data retrieved successfully for CHO in 2021.
# Data retrieved successfully for ORL in 2021.
# Data retrieved successfully for MIA in 2021.
# Data retrieved successfully for MIN in 2021.
# Data retrieved successfully for MEM in 2021.
# Data retrieved successfully for UTA in 2021.
# Data retrieved successfully for IND in 2021.
# Data retrieved successfully for NOP in 2021.
# Data retrieved successfully for BRK in 2021.
# Data retrieved successfully for PHO in 2021.
# Data retrieved successfully for WAS in 2021.
# Data retrieved successfully for NYK in 2021.
# Data retrieved successfully for HOU in 2021.
# Data retrieved successfully for PHI in 2021.
# Data retrieved successfully for LAC in 2021.
# Data retrieved successfully for LAL in 2021.
# Data retrieved successfully for ATL in 2021.
# Data retrieved successfully for OKC in 2021.
# Data retrieved successfully for SAS in 2021.
# Data retrieved successfully for CLE in 2021.
# Data retrieved successfully for DEN in 2021.
# Data retrieved successfully for CHI in 2021.
# Data retrieved successfully for BOS in 2021.
# Completed data collection for 2021.
# Data retrieved successfully for WAS in 2022.
# Data retrieved successfully for DET in 2022.
# Data retrieved successfully for PHI in 2022.
# Data retrieved successfully for HOU in 2022.
# Data retrieved successfully for NOP in 2022.
# Data retrieved successfully for CLE in 2022.
# Data retrieved successfully for LAL in 2022.
# Data retrieved successfully for MIN in 2022.
# Data retrieved successfully for BOS in 2022.
# Data retrieved successfully for MIA in 2022.
# Data retrieved successfully for NYK in 2022.
# Data retrieved successfully for ATL in 2022.
# Data retrieved successfully for MEM in 2022.
# Data retrieved successfully for PHO in 2022.
# Data retrieved successfully for CHI in 2022.
# Data retrieved successfully for SAC in 2022.
# Data retrieved successfully for CHO in 2022.
# Data retrieved successfully for UTA in 2022.
# Data retrieved successfully for TOR in 2022.
# Data retrieved successfully for ORL in 2022.
# Data retrieved successfully for SAS in 2022.
# Data retrieved successfully for MIL in 2022.
# Data retrieved successfully for GSW in 2022.
# Data retrieved successfully for DAL in 2022.
# Data retrieved successfully for POR in 2022.
# Data retrieved successfully for IND in 2022.
# Data retrieved successfully for LAC in 2022.
# Data retrieved successfully for BRK in 2022.
# Data retrieved successfully for OKC in 2022.
# Data retrieved successfully for DEN in 2022.
# Completed data collection for 2022.
# Data retrieved successfully for CHO in 2023.
# Data retrieved successfully for PHI in 2023.
# Data retrieved successfully for GSW in 2023.
# Data retrieved successfully for NYK in 2023.
# Data retrieved successfully for WAS in 2023.
# Data retrieved successfully for MIN in 2023.
# Data retrieved successfully for HOU in 2023.
# Data retrieved successfully for TOR in 2023.
# Data retrieved successfully for ORL in 2023.
# Data retrieved successfully for MIA in 2023.
# Data retrieved successfully for UTA in 2023.
# Data retrieved successfully for BRK in 2023.
# Data retrieved successfully for NOP in 2023.
# Data retrieved successfully for DEN in 2023.
# Data retrieved successfully for POR in 2023.
# Data retrieved successfully for ATL in 2023.
# Data retrieved successfully for MIL in 2023.
# Data retrieved successfully for BOS in 2023.
# Data retrieved successfully for DET in 2023.
# Data retrieved successfully for LAL in 2023.
# Data retrieved successfully for OKC in 2023.
# Data retrieved successfully for CHI in 2023.
# Data retrieved successfully for SAS in 2023.
# Data retrieved successfully for PHO in 2023.
# Data retrieved successfully for SAC in 2023.
# Data retrieved successfully for CLE in 2023.
# Data retrieved successfully for MEM in 2023.
# Data retrieved successfully for DAL in 2023.
# Data retrieved successfully for IND in 2023.
# Data retrieved successfully for LAC in 2023.
# Completed data collection for 2023.
# Data retrieved successfully for LAL in 2024.
# Data retrieved successfully for MIL in 2024.
# Data retrieved successfully for DET in 2024.
# Data retrieved successfully for CHI in 2024.
# Data retrieved successfully for UTA in 2024.
# Data retrieved successfully for POR in 2024.
# Data retrieved successfully for TOR in 2024.
# Data retrieved successfully for MEM in 2024.
# Data retrieved successfully for CHO in 2024.
# Data retrieved successfully for BOS in 2024.
# Data retrieved successfully for CLE in 2024.
# Data retrieved successfully for DEN in 2024.
# Data retrieved successfully for MIA in 2024.
# Data retrieved successfully for ATL in 2024.
# Data retrieved successfully for IND in 2024.
# Data retrieved successfully for ORL in 2024.
# Data retrieved successfully for NOP in 2024.
# Data retrieved successfully for PHO in 2024.
# Data retrieved successfully for OKC in 2024.
# Data retrieved successfully for BRK in 2024.
# Data retrieved successfully for NYK in 2024.
# Data retrieved successfully for HOU in 2024.
# Data retrieved successfully for DAL in 2024.
# Data retrieved successfully for SAS in 2024.
# Data retrieved successfully for WAS in 2024.
# Data retrieved successfully for LAC in 2024.
# Data retrieved successfully for GSW in 2024.
# Data retrieved successfully for SAC in 2024.
# Data retrieved successfully for MIN in 2024.
# Data retrieved successfully for PHI in 2024.
# Completed data collection for 2024.
# Data retrieved successfully for SAC in 2025.
# Data retrieved successfully for CLE in 2025.
# Data retrieved successfully for DET in 2025.
# Data retrieved successfully for GSW in 2025.
# Data retrieved successfully for PHI in 2025.
# Data retrieved successfully for CHO in 2025.
# Data retrieved successfully for POR in 2025.
# Data retrieved successfully for LAL in 2025.
# Data retrieved successfully for MIA in 2025.
# Data retrieved successfully for BOS in 2025.
# Data retrieved successfully for LAC in 2025.
# Data retrieved successfully for PHO in 2025.
# Data retrieved successfully for SAS in 2025.
# Data retrieved successfully for TOR in 2025.
# Data retrieved successfully for IND in 2025.
# Data retrieved successfully for NOP in 2025.
# Data retrieved successfully for WAS in 2025.
# Data retrieved successfully for ORL in 2025.
# Data retrieved successfully for OKC in 2025.
# Data retrieved successfully for MIL in 2025.
# Data retrieved successfully for MIN in 2025.
# Data retrieved successfully for ATL in 2025.
# Data retrieved successfully for MEM in 2025.
# Data retrieved successfully for HOU in 2025.
# Data retrieved successfully for UTA in 2025.
# Data retrieved successfully for DEN in 2025.
# Data retrieved successfully for DAL in 2025.
# Data retrieved successfully for BRK in 2025.
# Data retrieved successfully for CHI in 2025.
# Data retrieved successfully for NYK in 2025.
# Completed data collection for 2025.

# %%
print(boxscores_complete_new)
# Out:
#       Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                       Rk                Gtm               Date
# 0                      1                  1         2014-10-29
# 1                      2                  2         2014-10-31
# 2                     Rk                Gtm               Date
# 3                      3                  3         2014-11-01
# 4                      4                  4         2014-11-03
# ...                  ...                ...                ...
# 28701                 79                 79         2025-04-08
# 28702                 80                 80         2025-04-10
# 28703                 81                 81         2025-04-11
# 28704                 82                 82         2025-04-13
# 28705                NaN                NaN                NaN
#
#       Unnamed: 3_level_0 Unnamed: 4_level_0  Score                   Team  \
#       Unnamed: 3_level_1                Opp   Rslt    Tm   Opp   OT    FG
# 0                    NaN                MIN      W   105   101  NaN    43
# 1                      @                IND      W    97    89  NaN    35
# 2                    NaN                Opp   Rslt    Tm   Opp   OT    FG
# 3                      @                CHO      W    71    69  NaN    29
# 4                    NaN                NOP      W    93    81  NaN    31
# ...                  ...                ...    ...   ...   ...  ...   ...
# 28701                NaN                BOS      L   117   119   OT    48
# 28702                  @                DET      L   106   115  NaN    42
# 28703                NaN                CLE      L   102   108  NaN    36
# 28704                  @                BRK      W   113   105  NaN    37
# 28705                NaN                NaN  51-31  9494  9158  NaN  3553
#
#        ... Opponent                                         team season
#        ...      ORB   DRB   TRB   AST  STL  BLK   TOV    PF
# 0      ...       19    28    47    20    8    4    23    21  MEM   2015
# 1      ...       11    35    46    19    5    3    18    15  MEM   2015
# 2      ...      ORB   DRB   TRB   AST  STL  BLK   TOV    PF  MEM   2015
# 3      ...        5    39    44    17   10    4    20    16  MEM   2015
# 4      ...       14    35    49    14    5    3    12    30  MEM   2015
# ...    ...      ...   ...   ...   ...  ...  ...   ...   ...  ...    ...
# 28701  ...        9    29    38    26    8    4    15    17  NYK   2025
# 28702  ...        9    26    35    20    5    6    15    23  NYK   2025
# 28703  ...       13    36    49    23    7    2    15    17  NYK   2025
# 28704  ...        6    36    42    21    4    2    19    24  NYK   2025
# 28705  ...      893  2538  3431  2069  575  406  1189  1554  NYK   2025
#
# [28706 rows x 53 columns]

# %% [markdown]
# boxscores = pd.concat(
#     [
#         data_2014_df, data_2015_df, data_2016_df, data_2017_df,
#         data_2018_df, data_2019_df, data_2020_df, data_2021_df,
#         data_2022_df, data_2023_df, data_2024_df
#     ],
#     ignore_index=True
# )

# %%
# boxscores_complete_new.to_csv("BoxscoresDataset.csv", index=False)
boxscores_complete_new.to_csv("data/box_scores_randomized.csv", index=False)
